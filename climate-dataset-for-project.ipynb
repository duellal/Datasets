# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
from bq_helper import BigQueryHelper

# %%
climate_data = BigQueryHelper('bigquery-public-data', 'noaa_gsod')
# Out:
# Using Kaggle's public dataset BigQuery integration.

# %%
climate_data.list_tables()
# Out:
# ['gsod1929',
#  'gsod1930',
#  'gsod1931',
#  'gsod1932',
#  'gsod1933',
#  'gsod1934',
#  'gsod1935',
#  'gsod1936',
#  'gsod1937',
#  'gsod1938',
#  'gsod1939',
#  'gsod1940',
#  'gsod1941',
#  'gsod1942',
#  'gsod1943',
#  'gsod1944',
#  'gsod1945',
#  'gsod1946',
#  'gsod1947',
#  'gsod1948',
#  'gsod1949',
#  'gsod1950',
#  'gsod1951',
#  'gsod1952',
#  'gsod1953',
#  'gsod1954',
#  'gsod1955',
#  'gsod1956',
#  'gsod1957',
#  'gsod1958',
#  'gsod1959',
#  'gsod1960',
#  'gsod1961',
#  'gsod1962',
#  'gsod1963',
#  'gsod1964',
#  'gsod1965',
#  'gsod1966',
#  'gsod1967',
#  'gsod1968',
#  'gsod1969',
#  'gsod1970',
#  'gsod1971',
#  'gsod1972',
#  'gsod1973',
#  'gsod1974',
#  'gsod1975',
#  'gsod1976',
#  'gsod1977',
#  'gsod1978',
#  'gsod1979',
#  'gsod1980',
#  'gsod1981',
#  'gsod1982',
#  'gsod1983',
#  'gsod1984',
#  'gsod1985',
#  'gsod1986',
#  'gsod1987',
#  'gsod1988',
#  'gsod1989',
#  'gsod1990',
#  'gsod1991',
#  'gsod1992',
#  'gsod1993',
#  'gsod1994',
#  'gsod1995',
#  'gsod1996',
#  'gsod1997',
#  'gsod1998',
#  'gsod1999',
#  'gsod2000',
#  'gsod2001',
#  'gsod2002',
#  'gsod2003',
#  'gsod2004',
#  'gsod2005',
#  'gsod2006',
#  'gsod2007',
#  'gsod2008',
#  'gsod2009',
#  'gsod2010',
#  'gsod2011',
#  'gsod2012',
#  'gsod2013',
#  'gsod2014',
#  'gsod2015',
#  'gsod2016',
#  'gsod2017',
#  'gsod2018',
#  'gsod2019',
#  'gsod2020',
#  'gsod2021',
#  'stations']

# %%
climate_data.head('gsod2020', num_rows=3)
# Out:
#       stn   wban        date  year  mo  da  temp  count_temp    dewp  \
# 0  041310  99999  2020-08-04  2020  08  04  44.8          14  9999.9
# 1  071200  99999  2020-09-30  2020  09  30  53.3          24  9999.9
# 2  074910  99999  2020-10-23  2020  10  23  52.8          24  9999.9
#
#    count_dewp  ...  flag_min  prcp  flag_prcp   sndp  fog  rain_drizzle  \
# 0           0  ...      None  0.00          I  999.9    0             0
# 1           0  ...         *  0.09          G  999.9    1             0
# 2           0  ...         *  0.59          G  999.9    1             0
#
#   snow_ice_pellets hail thunder  tornado_funnel_cloud
# 0                0    0       0                     0
# 1                0    0       0                 10000
# 2                0    0       0                 10000
#
# [3 rows x 33 columns]

# %%
climate_data.table_schema("gsod2020")
# Out:
#                     name     type      mode  \
# 0                    stn   STRING  NULLABLE
# 1                   wban   STRING  NULLABLE
# 2                   date     DATE  NULLABLE
# 3                   year   STRING  NULLABLE
# 4                     mo   STRING  NULLABLE
# 5                     da   STRING  NULLABLE
# 6                   temp    FLOAT  NULLABLE
# 7             count_temp  INTEGER  NULLABLE
# 8                   dewp    FLOAT  NULLABLE
# 9             count_dewp  INTEGER  NULLABLE
# 10                   slp    FLOAT  NULLABLE
# 11             count_slp  INTEGER  NULLABLE
# 12                   stp    FLOAT  NULLABLE
# 13             count_stp  INTEGER  NULLABLE
# 14                 visib    FLOAT  NULLABLE
# 15           count_visib  INTEGER  NULLABLE
# 16                  wdsp   STRING  NULLABLE
# 17            count_wdsp   STRING  NULLABLE
# 18                 mxpsd   STRING  NULLABLE
# 19                  gust    FLOAT  NULLABLE
# 20                   max    FLOAT  NULLABLE
# 21              flag_max   STRING  NULLABLE
# 22                   min    FLOAT  NULLABLE
# 23              flag_min   STRING  NULLABLE
# 24                  prcp    FLOAT  NULLABLE
# 25             flag_prcp   STRING  NULLABLE
# 26                  sndp    FLOAT  NULLABLE
# 27                   fog   STRING  NULLABLE
# 28          rain_drizzle   STRING  NULLABLE
# 29      snow_ice_pellets   STRING  NULLABLE
# 30                  hail   STRING  NULLABLE
# 31               thunder   STRING  NULLABLE
# 32  tornado_funnel_cloud   STRING  NULLABLE
#
#                                           description
# 0                                   Cloud - GSOD NOAA
# 1   WBAN number where applicable--this is the hist...
# 2                    Date of the weather observations
# 3                                            The year
# 4                                           The month
# 5                                             The day
# 6   Mean temperature for the day in degrees Fahren...
# 7   Number of observations used in calculating mea...
# 8   Mean dew point for the day in degreesm Fahrenh...
# 9   Number of observations used in calculating mea...
# 10  Mean sea level pressure for the day in milliba...
# 11  Number of observations used in calculating mea...
# 12  Mean station pressure for the day in millibars...
# 13  Number of observations used in calculating mea...
# 14  Mean visibility for the day in miles to tenths...
# 15  Number of observations used in calculating mea...
# 16  Mean wind speed for the day in knots to tenths...
# 17  Number of observations used in calculating mea...
# 18  Maximum sustained wind speed reported for the ...
# 19  Maximum wind gust reported for the day in knot...
# 20  Maximum temperature reported during the day in...
# 21  Blank indicates max temp was taken from the ex...
# 22  Minimum temperature reported during the day in...
# 23  Blank indicates min temp was taken from the ex...
# 24  Total precipitation (rain and/or melted snow) ...
# 25  A = 1 report of 6-hour precipitation amount B ...
# 26  Snow depth in inches to tenths--last report fo...
# 27  Indicators (1 = yes, 0 = no/not reported) for ...
# 28  Indicators (1 = yes, 0 = no/not reported) for ...
# 29  Indicators (1 = yes, 0 = no/not reported) for ...
# 30  Indicators (1 = yes, 0 = no/not reported) for ...
# 31  Indicators (1 = yes, 0 = no/not reported) for ...
# 32  Indicators (1 = yes, 0 = no/not reported) for ...
